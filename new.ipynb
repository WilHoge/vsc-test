# %%
# Assisted by WCA@IBM
# Latest GenAI contribution: ibm/granite-20b-code-instruct-v2
import numpy as np
from sklearn.linear_model import LinearRegression

# Define the input data (X) and target (y)
X = [[1], [2], [3], [4]]
y = [1, 2, 3, 4]

# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# Make predictions using the model
predictions = model.predict([[5]])

# Print the predictions
print(predictions)
# Out:
# [5.]

# %%
# Assisted by WCA@IBM
# Latest GenAI contribution: ibm/granite-20b-code-instruct-v2
import pandas as pd

# Specify the URL of the CSV file in the GitHub repository
url = "https://raw.githubusercontent.com/WilHoge/NYC-taxi-viz/master/data/taxi-av100000.csv"

# Read the CSV data into a pandas DataFrame
df = pd.read_csv(url)

# Print the first few rows of the DataFrame
df.head()
# Out:
#    Unnamed: 0 Vendor        pickup.datetime       dropoff.datetime  \
# 0           1    VTS  2013-04-15 20:30:00.0  2013-04-15 20:39:00.0
# 1           2    VTS  2013-04-15 23:55:00.0  2013-04-15 23:59:00.0
# 2           3    VTS  2013-04-16 07:59:00.0  2013-04-16 08:14:00.0
# 3           4    VTS  2013-04-04 13:41:00.0  2013-04-04 13:46:00.0
# 4           5    VTS  2013-04-04 14:12:00.0  2013-04-04 14:35:00.0
#
#    passenger.count  trip.time  trip.distance  pickup.longitude  \
# 0                1        540           1.63        -73.983177
# 1                2        240           1.33        -73.949974
# 2                3        900           2.86        -73.966537
# 3                1        300           0.57        -73.977150
# 4                1       1380           9.58        -73.982307
#
#    pickup.latitude  dropoff.longitude  ...  Day Hour  Temperature  \
# 0        40.756702         -73.977386  ...   15   20          9.4
# 1        40.776089         -73.964874  ...   15   23          8.9
# 2        40.794365         -73.982155  ...   16    7          9.4
# 3        40.751736         -73.972336  ...    4   13          8.3
# 4        40.751774         -73.865692  ...    4   14          9.4
#
#    Precipitation  pickup.date   weekday  weekend  rain  fare.per.mile  \
# 0            0.0   2013-04-15    Monday       no    no       5.214724
# 1            0.0   2013-04-15    Monday       no    no       4.511278
# 2            0.0   2013-04-16   Tuesday       no    no       4.370629
# 3            0.0   2013-04-04  Thursday       no    no       8.771930
# 4            0.0   2013-04-04  Thursday       no    no       3.027140
#
#        speed
# 0  10.866667
# 1  19.950000
# 2  11.440000
# 3   6.840000
# 4  24.991304
#
# [5 rows x 30 columns]

# %%
# Assisted by WCA@IBM
# Latest GenAI contribution: ibm/granite-20b-code-instruct-v2
import pandas as pd
import os

# Upload the file to your Watson Studio project
from ibm_watson_studio_lib import access_project_or_space
credentials_dic={"project_id":os.getenv("PROJECT_ID"), "token":os.getenv("USER_ACCESS_TOKEN")}
wslib = access_project_or_space(params=credentials_dic)

wslib.save_data("my_asset_name.csv", df.to_csv(index=False).encode())
# Out:
# {'name': 'my_asset_name.csv',
#  'asset_type': 'data_asset',
#  'asset_id': 'data_asset.myassetnamecsv',
#  'attachment_id': '802226cb-7d08-4c79-b5b1-80e961701425',
#  'filepath': 'my_asset_name.csv',
#  'data_size': None,
#  'mime': 'text/csv',
#  'summary': ['created file', 'created data asset', 'created attachment']}
